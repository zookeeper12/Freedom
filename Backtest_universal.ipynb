# %%
#Create imports for modules
import fxcmpy
import pandas as pd
import numpy as np
import datetime as dt

#import funcs
from pyti.bollinger_bands import upper_bollinger_band as ubb
from pyti.bollinger_bands import middle_bollinger_band as mbb
from pyti.bollinger_bands import lower_bollinger_band as lbb
from pyti.bollinger_bands import percent_bandwidth as percent_b

#import plots and styling
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
style.use('ggplot')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
socket = fxcmpy.fxcmpy(config_file = 'fxcm.cfg')
print (socket.get_instruments_for_candles())
# Out:
# ['EUR/USD', 'USD/JPY', 'USD/CHF', 'AUD/USD', 'NZD/USD', 'GBP/JPY', 'AUD/JPY', 'AUS200', 'GER30', 'UK100', 'US30', 'USDOLLAR', 'XAG/USD']

# %%
data = socket.get_candles(instrument = 'US30', period = 'm1', start = dt.datetime(2019,8,5), end = dt.datetime(2019, 8, 9))

# %%
#Define useful variables


data['upper_band'] = ubb(data['askclose'], period = 20)
data['mid_band'] = mbb(data['askclose'], period = 20 )
data['lower_band'] = lbb(data['askclose'], period = 20 )
data['percent_b'] = percent_b(data['askclose'], period =20)

data.tail(20)
# Out:
#                      bidopen  bidclose  bidhigh   bidlow  askopen  askclose  \
# date
# 2019-08-08 23:41:00  26267.9   26273.4  26276.9  26266.1  26270.0   26275.6
# 2019-08-08 23:42:00  26273.4   26270.6  26273.4  26267.9  26275.6   26272.7
# 2019-08-08 23:43:00  26270.6   26301.9  26303.7  26269.1  26272.7   26304.1
# 2019-08-08 23:44:00  26301.9   26314.9  26322.0  26299.1  26304.1   26317.0
# 2019-08-08 23:45:00  26314.9   26345.4  26349.0  26309.9  26317.0   26347.7
# 2019-08-08 23:46:00  26345.4   26342.1  26353.1  26336.9  26347.7   26344.3
# 2019-08-08 23:47:00  26342.1   26361.6  26364.5  26333.9  26344.3   26363.8
# 2019-08-08 23:48:00  26361.6   26344.6  26362.1  26339.9  26363.8   26346.8
# 2019-08-08 23:49:00  26344.6   26341.8  26350.2  26336.9  26346.8   26343.6
# 2019-08-08 23:50:00  26341.8   26341.6  26347.4  26333.9  26343.6   26343.5
# 2019-08-08 23:51:00  26341.6   26340.9  26351.0  26338.1  26343.5   26343.1
# 2019-08-08 23:52:00  26340.9   26342.0  26343.5  26336.6  26343.1   26344.6
# 2019-08-08 23:53:00  26342.0   26342.4  26342.7  26333.9  26344.6   26344.3
# 2019-08-08 23:54:00  26342.4   26340.6  26343.6  26336.9  26344.3   26342.6
# 2019-08-08 23:55:00  26340.6   26342.9  26342.9  26333.9  26342.6   26345.0
# 2019-08-08 23:56:00  26342.9   26336.4  26343.6  26333.9  26345.0   26338.6
# 2019-08-08 23:57:00  26336.4   26346.0  26346.0  26335.6  26338.6   26348.1
# 2019-08-08 23:58:00  26346.0   26346.1  26349.0  26336.9  26348.1   26348.1
# 2019-08-08 23:59:00  26346.1   26354.1  26359.0  26339.9  26348.1   26355.5
# 2019-08-09 00:00:00  26354.1   26348.9  26359.5  26339.9  26355.5   26353.0
#
#                      askhigh   asklow  tickqty    upper_band   mid_band  \
# date
# 2019-08-08 23:41:00  26280.1  26268.2      260  26278.489474  26255.290
# 2019-08-08 23:42:00  26276.8  26271.5      117  26280.642923  26256.545
# 2019-08-08 23:43:00  26310.1  26270.8      615  26290.769757  26259.340
# 2019-08-08 23:44:00  26325.1  26302.0     1073  26302.521908  26262.810
# 2019-08-08 23:45:00  26355.1  26312.1      979  26321.361746  26267.890
# 2019-08-08 23:46:00  26358.1  26339.3      877  26334.652182  26272.900
# 2019-08-08 23:47:00  26370.1  26337.8      692  26350.681140  26278.900
# 2019-08-08 23:48:00  26367.1  26346.2      636  26359.666134  26284.075
# 2019-08-08 23:49:00  26355.1  26342.3      475  26366.354441  26289.180
# 2019-08-08 23:50:00  26352.1  26337.8      545  26371.533820  26294.350
# 2019-08-08 23:51:00  26355.1  26340.8      380  26375.817412  26299.210
# 2019-08-08 23:52:00  26346.1  26338.1      330  26379.918228  26303.685
# 2019-08-08 23:53:00  26345.6  26336.8      350  26383.087321  26308.045
# 2019-08-08 23:54:00  26346.1  26342.3      210  26384.969696  26312.320
# 2019-08-08 23:55:00  26346.1  26337.6      310  26387.044809  26316.235
# 2019-08-08 23:56:00  26346.1  26338.1      264  26387.411515  26319.845
# 2019-08-08 23:57:00  26349.1  26337.5      291  26388.394369  26323.710
# 2019-08-08 23:58:00  26352.1  26340.2      425  26388.027057  26327.660
# 2019-08-08 23:59:00  26364.1  26343.2      447  26387.210347  26331.950
# 2019-08-09 00:00:00  26362.4  26342.6     1188  26384.119538  26336.100
#
#                        lower_band  percent_b
# date
# 2019-08-08 23:41:00  26232.090526   0.937725
# 2019-08-08 23:42:00  26232.447077   0.835195
# 2019-08-08 23:43:00  26227.910243   1.212064
# 2019-08-08 23:44:00  26223.098092   1.182289
# 2019-08-08 23:45:00  26214.418254   1.246282
# 2019-08-08 23:46:00  26211.147818   1.078117
# 2019-08-08 23:47:00  26207.118860   1.091381
# 2019-08-08 23:48:00  26208.483866   0.914897
# 2019-08-08 23:49:00  26212.005559   0.852578
# 2019-08-08 23:50:00  26217.166180   0.818396
# 2019-08-08 23:51:00  26222.602588   0.786461
# 2019-08-08 23:52:00  26227.451772   0.768354
# 2019-08-08 23:53:00  26233.002679   0.741564
# 2019-08-08 23:54:00  26239.670304   0.708397
# 2019-08-08 23:55:00  26245.425191   0.703115
# 2019-08-08 23:56:00  26252.278485   0.638789
# 2019-08-08 23:57:00  26259.025631   0.688531
# 2019-08-08 23:58:00  26267.292943   0.669298
# 2019-08-08 23:59:00  26276.689653   0.713082
# 2019-08-09 00:00:00  26288.080462   0.675970

# %%
fig = plt.figure(figsize=(12,8))

ax1 = fig.add_subplot(111,  xlabel = 'Date',ylabel='Close')


data['askclose'].plot(ax=ax1, color='r', lw=1)
data['upper_band'].plot(ax=ax1, color = 'b', lw= 1)
data['mid_band'].plot(ax=ax1, color = 'g', lw= 1)
data['lower_band'].plot(ax=ax1, color = 'y', lw= 1)

# %%
#For reference
#%B Above 1 = Price is Above the Upper Band
#%B Equal to 1 = Price is at the Upper Band
#%B Above .50 = Price is Above the Middle Line
#%B Below .50 = Price is Below the Middle Line
#%B Equal to 0 = Price is at the Lower Band
#%B Below 0 = Price is Below the Lower Band
#%B Above .80 = Price is Nearing the Upper Band
#%B Below .20 = Price is Nearing the Lower Band

# %%
data.tail(10)
# Out:
#                      bidopen  bidclose  bidhigh   bidlow  askopen  askclose  \
# date
# 2019-08-08 23:51:00  26341.6   26340.9  26351.0  26338.1  26343.5   26343.1
# 2019-08-08 23:52:00  26340.9   26342.0  26343.5  26336.6  26343.1   26344.6
# 2019-08-08 23:53:00  26342.0   26342.4  26342.7  26333.9  26344.6   26344.3
# 2019-08-08 23:54:00  26342.4   26340.6  26343.6  26336.9  26344.3   26342.6
# 2019-08-08 23:55:00  26340.6   26342.9  26342.9  26333.9  26342.6   26345.0
# 2019-08-08 23:56:00  26342.9   26336.4  26343.6  26333.9  26345.0   26338.6
# 2019-08-08 23:57:00  26336.4   26346.0  26346.0  26335.6  26338.6   26348.1
# 2019-08-08 23:58:00  26346.0   26346.1  26349.0  26336.9  26348.1   26348.1
# 2019-08-08 23:59:00  26346.1   26354.1  26359.0  26339.9  26348.1   26355.5
# 2019-08-09 00:00:00  26354.1   26348.9  26359.5  26339.9  26355.5   26353.0
#
#                      askhigh   asklow  tickqty    upper_band   mid_band  \
# date
# 2019-08-08 23:51:00  26355.1  26340.8      380  26375.817412  26299.210
# 2019-08-08 23:52:00  26346.1  26338.1      330  26379.918228  26303.685
# 2019-08-08 23:53:00  26345.6  26336.8      350  26383.087321  26308.045
# 2019-08-08 23:54:00  26346.1  26342.3      210  26384.969696  26312.320
# 2019-08-08 23:55:00  26346.1  26337.6      310  26387.044809  26316.235
# 2019-08-08 23:56:00  26346.1  26338.1      264  26387.411515  26319.845
# 2019-08-08 23:57:00  26349.1  26337.5      291  26388.394369  26323.710
# 2019-08-08 23:58:00  26352.1  26340.2      425  26388.027057  26327.660
# 2019-08-08 23:59:00  26364.1  26343.2      447  26387.210347  26331.950
# 2019-08-09 00:00:00  26362.4  26342.6     1188  26384.119538  26336.100
#
#                        lower_band  percent_b
# date
# 2019-08-08 23:51:00  26222.602588   0.786461
# 2019-08-08 23:52:00  26227.451772   0.768354
# 2019-08-08 23:53:00  26233.002679   0.741564
# 2019-08-08 23:54:00  26239.670304   0.708397
# 2019-08-08 23:55:00  26245.425191   0.703115
# 2019-08-08 23:56:00  26252.278485   0.638789
# 2019-08-08 23:57:00  26259.025631   0.688531
# 2019-08-08 23:58:00  26267.292943   0.669298
# 2019-08-08 23:59:00  26276.689653   0.713082
# 2019-08-09 00:00:00  26288.080462   0.675970

# %%
#Define the strategy
buy_prices = []
sell_prices = []

order = False
for i, row in data.iterrows():
    #buy
    if row['percent_b'] <= .2 and order == False:
        print("Create buy order since percent_b under 20%")
        print("Price bought: " +str(float(row['askopen'])))
        buy_prices.append(float(row['askopen']))
        order = True
    # close buy order
    if row['percent_b'] >= .75 and order == True:
        print("Create sell order since percent_b over 80%")
        print("Price sold: " +str(float(row['askopen'])))
        sell_prices.append(float(row['askopen']))
        order = False
# Out:
# Create buy order since percent_b under 20%
# Price bought: 26453.1
# Create sell order since percent_b over 80%
# Price sold: 26455.7
# Create buy order since percent_b under 20%
# Price bought: 26498.1
# Create sell order since percent_b over 80%
# Price sold: 26319.2
# Create buy order since percent_b under 20%
# Price bought: 26311.9
# Create sell order since percent_b over 80%
# Price sold: 26189.9
# Create buy order since percent_b under 20%
# Price bought: 26204.3
# Create sell order since percent_b over 80%
# Price sold: 26202.1
# Create buy order since percent_b under 20%
# Price bought: 26196.7
# Create sell order since percent_b over 80%
# Price sold: 26198.6
# Create buy order since percent_b under 20%
# Price bought: 26237.5
# Create sell order since percent_b over 80%
# Price sold: 26225.6
# Create buy order since percent_b under 20%
# Price bought: 26228.4
# Create sell order since percent_b over 80%
# Price sold: 26227.7
# Create buy order since percent_b under 20%
# Price bought: 26243.5
# Create sell order since percent_b over 80%
# Price sold: 26210.6
# Create buy order since percent_b under 20%
# Price bought: 26210.7
# Create sell order since percent_b over 80%
# Price sold: 26158.9
# Create buy order since percent_b under 20%
# Price bought: 26164.0
# Create sell order since percent_b over 80%
# Price sold: 26131.1
# Create buy order since percent_b under 20%
# Price bought: 26130.6
# Create sell order since percent_b over 80%
# Price sold: 26114.8
# Create buy order since percent_b under 20%
# Price bought: 26210.3
# Create sell order since percent_b over 80%
# Price sold: 26218.1
# Create buy order since percent_b under 20%
# Price bought: 26214.2
# Create sell order since percent_b over 80%
# Price sold: 26163.4
# Create buy order since percent_b under 20%
# Price bought: 26169.2
# Create sell order since percent_b over 80%
# Price sold: 26105.6
# Create buy order since percent_b under 20%
# Price bought: 26146.8
# Create sell order since percent_b over 80%
# Price sold: 26154.1
# Create buy order since percent_b under 20%
# Price bought: 26146.7
# Create sell order since percent_b over 80%
# Price sold: 26151.7
# Create buy order since percent_b under 20%
# Price bought: 26146.7
# Create sell order since percent_b over 80%
# Price sold: 26122.0
# Create buy order since percent_b under 20%
# Price bought: 26121.4
# Create sell order since percent_b over 80%
# Price sold: 25999.7
# Create buy order since percent_b under 20%
# Price bought: 25984.5
# Create sell order since percent_b over 80%
# Price sold: 25909.1
# Create buy order since percent_b under 20%
# Price bought: 25965.1
# Create sell order since percent_b over 80%
# Price sold: 25930.0
# Create buy order since percent_b under 20%
# Price bought: 25919.5
# Create sell order since percent_b over 80%
# Price sold: 25906.2
# Create buy order since percent_b under 20%
# Price bought: 25889.8
# Create sell order since percent_b over 80%
# Price sold: 25780.7
# Create buy order since percent_b under 20%
# Price bought: 25787.1
# Create sell order since percent_b over 80%
# Price sold: 25799.3
# Create buy order since percent_b under 20%
# Price bought: 25770.5
# Create sell order since percent_b over 80%
# Price sold: 25742.6
# Create buy order since percent_b under 20%
# Price bought: 25731.0
# Create sell order since percent_b over 80%
# Price sold: 25636.5
# Create buy order since percent_b under 20%
# Price bought: 25617.5
# Create sell order since percent_b over 80%
# Price sold: 25568.9
# Create buy order since percent_b under 20%
# Price bought: 25636.4
# Create sell order since percent_b over 80%
# Price sold: 25679.7
# Create buy order since percent_b under 20%
# Price bought: 25726.9
# Create sell order since percent_b over 80%
# Price sold: 25252.1
# Create buy order since percent_b under 20%
# Price bought: 25276.9
# Create sell order since percent_b over 80%
# Price sold: 25230.9
# Create buy order since percent_b under 20%
# Price bought: 25257.2
# Create sell order since percent_b over 80%
# Price sold: 25140.2
# Create buy order since percent_b under 20%
# Price bought: 25247.9
# Create sell order since percent_b over 80%
# Price sold: 25263.8
# Create buy order since percent_b under 20%
# Price bought: 25417.7
# Create sell order since percent_b over 80%
# Price sold: 25420.4
# Create buy order since percent_b under 20%
# Price bought: 25399.0
# Create sell order since percent_b over 80%
# Price sold: 25373.5
# Create buy order since percent_b under 20%
# Price bought: 25702.1
# Create sell order since percent_b over 80%
# Price sold: 25599.0
# Create buy order since percent_b under 20%
# Price bought: 25662.6
# Create sell order since percent_b over 80%
# Price sold: 25638.6
# Create buy order since percent_b under 20%
# Price bought: 25659.0
# Create sell order since percent_b over 80%
# Price sold: 25663.9
# Create buy order since percent_b under 20%
# Price bought: 25669.3
# Create sell order since percent_b over 80%
# Price sold: 25670.3
# Create buy order since percent_b under 20%
# Price bought: 25741.7
# Create sell order since percent_b over 80%
# Price sold: 25684.2
# Create buy order since percent_b under 20%
# Price bought: 25791.8
# Create sell order since percent_b over 80%
# Price sold: 25794.8
# Create buy order since percent_b under 20%
# Price bought: 25828.4
# Create sell order since percent_b over 80%
# Price sold: 25800.4
# Create buy order since percent_b under 20%
# Price bought: 25816.9
# Create sell order since percent_b over 80%
# Price sold: 25796.4
# Create buy order since percent_b under 20%
# Price bought: 25856.6
# Create sell order since percent_b over 80%
# Price sold: 25820.3
# Create buy order since percent_b under 20%
# Price bought: 25814.4
# Create sell order since percent_b over 80%
# Price sold: 25813.0
# Create buy order since percent_b under 20%
# Price bought: 25892.8
# Create sell order since percent_b over 80%
# Price sold: 25886.9
# Create buy order since percent_b under 20%
# Price bought: 25854.9
# Create sell order since percent_b over 80%
# Price sold: 25793.8
# Create buy order since percent_b under 20%
# Price bought: 25823.3
# Create sell order since percent_b over 80%
# Price sold: 25764.0
# Create buy order since percent_b under 20%
# Price bought: 25827.5
# Create sell order since percent_b over 80%
# Price sold: 25801.9
# Create buy order since percent_b under 20%
# Price bought: 25791.5
# Create sell order since percent_b over 80%
# Price sold: 25800.9
# Create buy order since percent_b under 20%
# Price bought: 25903.1
# Create sell order since percent_b over 80%
# Price sold: 25903.7
# Create buy order since percent_b under 20%
# Price bought: 25979.7
# Create sell order since percent_b over 80%
# Price sold: 25958.3
# Create buy order since percent_b under 20%
# Price bought: 25972.5
# Create sell order since percent_b over 80%
# Price sold: 25977.3
# Create buy order since percent_b under 20%
# Price bought: 26026.4
# Create sell order since percent_b over 80%
# Price sold: 25985.7
# Create buy order since percent_b under 20%
# Price bought: 25976.7
# Create sell order since percent_b over 80%
# Price sold: 25958.2
# Create buy order since percent_b under 20%
# Price bought: 25958.3
# Create sell order since percent_b over 80%
# Price sold: 25879.0
# Create buy order since percent_b under 20%
# Price bought: 25881.5
# Create sell order since percent_b over 80%
# Price sold: 25885.3
# Create buy order since percent_b under 20%
# Price bought: 25897.3
# Create sell order since percent_b over 80%
# Price sold: 25877.3
# Create buy order since percent_b under 20%
# Price bought: 25877.0
# Create sell order since percent_b over 80%
# Price sold: 25881.2
# Create buy order since percent_b under 20%
# Price bought: 25922.8
# Create sell order since percent_b over 80%
# Price sold: 25859.9
# Create buy order since percent_b under 20%
# Price bought: 25872.6
# Create sell order since percent_b over 80%
# Price sold: 25812.4
# Create buy order since percent_b under 20%
# Price bought: 25821.5
# Create sell order since percent_b over 80%
# Price sold: 25811.0
# Create buy order since percent_b under 20%
# Price bought: 25861.6
# Create sell order since percent_b over 80%
# Price sold: 25831.6
# Create buy order since percent_b under 20%
# Price bought: 25896.1
# Create sell order since percent_b over 80%
# Price sold: 25894.7
# Create buy order since percent_b under 20%
# Price bought: 25890.8
# Create sell order since percent_b over 80%
# Price sold: 25877.4
# Create buy order since percent_b under 20%
# Price bought: 25933.0
# Create sell order since percent_b over 80%
# Price sold: 25913.7
# Create buy order since percent_b under 20%
# Price bought: 25994.1
# Create sell order since percent_b over 80%
# Price sold: 25990.9
# Create buy order since percent_b under 20%
# Price bought: 26034.3
# Create sell order since percent_b over 80%
# Price sold: 26021.0
# Create buy order since percent_b under 20%
# Price bought: 26076.1
# Create sell order since percent_b over 80%
# Price sold: 26063.7
# Create buy order since percent_b under 20%
# Price bought: 26067.6
# Create sell order since percent_b over 80%
# Price sold: 26035.3
# Create buy order since percent_b under 20%
# Price bought: 26037.8
# Create sell order since percent_b over 80%
# Price sold: 25857.2
# Create buy order since percent_b under 20%
# Price bought: 25833.8
# Create sell order since percent_b over 80%
# Price sold: 25711.8
# Create buy order since percent_b under 20%
# Price bought: 25702.7
# Create sell order since percent_b over 80%
# Price sold: 25510.7
# Create buy order since percent_b under 20%
# Price bought: 25633.4
# Create sell order since percent_b over 80%
# Price sold: 25650.1
# Create buy order since percent_b under 20%
# Price bought: 25719.3
# Create sell order since percent_b over 80%
# Price sold: 25767.5
# Create buy order since percent_b under 20%
# Price bought: 25720.3
# Create sell order since percent_b over 80%
# Price sold: 25678.2
# Create buy order since percent_b under 20%
# Price bought: 25663.5
# Create sell order since percent_b over 80%
# Price sold: 25680.2
# Create buy order since percent_b under 20%
# Price bought: 25661.7
# Create sell order since percent_b over 80%
# Price sold: 25678.7
# Create buy order since percent_b under 20%
# Price bought: 25821.4
# Create sell order since percent_b over 80%
# Price sold: 25824.8
# Create buy order since percent_b under 20%
# Price bought: 25920.8
# Create sell order since percent_b over 80%
# Price sold: 25947.8
# Create buy order since percent_b under 20%
# Price bought: 25934.7
# Create sell order since percent_b over 80%
# Price sold: 25923.6
# Create buy order since percent_b under 20%
# Price bought: 26004.3
# Create sell order since percent_b over 80%
# Price sold: 25983.2
# Create buy order since percent_b under 20%
# Price bought: 26023.6
# Create sell order since percent_b over 80%
# Price sold: 26042.6
# Create buy order since percent_b under 20%
# Price bought: 25978.5
# Create sell order since percent_b over 80%
# Price sold: 25978.5
# Create buy order since percent_b under 20%
# Price bought: 25984.3
# Create sell order since percent_b over 80%
# Price sold: 25950.6
# Create buy order since percent_b under 20%
# Price bought: 25983.6
# Create sell order since percent_b over 80%
# Price sold: 25985.5
# Create buy order since percent_b under 20%
# Price bought: 25981.0
# Create sell order since percent_b over 80%
# Price sold: 25988.2
# Create buy order since percent_b under 20%
# Price bought: 25981.6
# Create sell order since percent_b over 80%
# Price sold: 25917.0
# Create buy order since percent_b under 20%
# Price bought: 25912.2
# Create sell order since percent_b over 80%
# Price sold: 25894.8
# Create buy order since percent_b under 20%
# Price bought: 26023.9
# Create sell order since percent_b over 80%
# Price sold: 25976.3
# Create buy order since percent_b under 20%
# Price bought: 26057.0
# Create sell order since percent_b over 80%
# Price sold: 26059.0
# Create buy order since percent_b under 20%
# Price bought: 26052.8
# Create sell order since percent_b over 80%
# Price sold: 26039.4
# Create buy order since percent_b under 20%
# Price bought: 26062.4
# Create sell order since percent_b over 80%
# Price sold: 26059.4
# Create buy order since percent_b under 20%
# Price bought: 26052.7
# Create sell order since percent_b over 80%
# Price sold: 26058.3
# Create buy order since percent_b under 20%
# Price bought: 26076.5
# Create sell order since percent_b over 80%
# Price sold: 26077.2
# Create buy order since percent_b under 20%
# Price bought: 26078.5
# Create sell order since percent_b over 80%
# Price sold: 26005.0
# Create buy order since percent_b under 20%
# Price bought: 26024.0
# Create sell order since percent_b over 80%
# Price sold: 25983.1
# Create buy order since percent_b under 20%
# Price bought: 26016.3
# Create sell order since percent_b over 80%
# Price sold: 26020.1
# Create buy order since percent_b under 20%
# Price bought: 26031.3
# Create sell order since percent_b over 80%
# Price sold: 26023.5
# Create buy order since percent_b under 20%
# Price bought: 26030.0
# Create sell order since percent_b over 80%
# Price sold: 25972.7
# Create buy order since percent_b under 20%
# Price bought: 25990.4
# Create sell order since percent_b over 80%
# Price sold: 25988.9
# Create buy order since percent_b under 20%
# Price bought: 26026.4
# Create sell order since percent_b over 80%
# Price sold: 26026.3
# Create buy order since percent_b under 20%
# Price bought: 26109.3
# Create sell order since percent_b over 80%
# Price sold: 26084.9
# Create buy order since percent_b under 20%
# Price bought: 26138.0
# Create sell order since percent_b over 80%
# Price sold: 26134.7
# Create buy order since percent_b under 20%
# Price bought: 26163.5
# Create sell order since percent_b over 80%
# Price sold: 26165.4
# Create buy order since percent_b under 20%
# Price bought: 26316.1
# Create sell order since percent_b over 80%
# Price sold: 26298.1
# Create buy order since percent_b under 20%
# Price bought: 26313.6
# Create sell order since percent_b over 80%
# Price sold: 26285.5
# Create buy order since percent_b under 20%
# Price bought: 26301.0
# Create sell order since percent_b over 80%
# Price sold: 26298.8
# Create buy order since percent_b under 20%
# Price bought: 26296.0
# Create sell order since percent_b over 80%
# Price sold: 26283.0
# Create buy order since percent_b under 20%
# Price bought: 26388.2
# Create sell order since percent_b over 80%
# Price sold: 26388.2
# Create buy order since percent_b under 20%
# Price bought: 26389.5
# Create sell order since percent_b over 80%
# Price sold: 26228.8
# Create buy order since percent_b under 20%
# Price bought: 26260.3
# Create sell order since percent_b over 80%
# Price sold: 26245.9

# %%
buy_prices
# Out:
# [26453.1,
#  26498.1,
#  26311.9,
#  26204.3,
#  26196.7,
#  26237.5,
#  26228.4,
#  26243.5,
#  26210.7,
#  26164.0,
#  26130.6,
#  26210.3,
#  26214.2,
#  26169.2,
#  26146.8,
#  26146.7,
#  26146.7,
#  26121.4,
#  25984.5,
#  25965.1,
#  25919.5,
#  25889.8,
#  25787.1,
#  25770.5,
#  25731.0,
#  25617.5,
#  25636.4,
#  25726.9,
#  25276.9,
#  25257.2,
#  25247.9,
#  25417.7,
#  25399.0,
#  25702.1,
#  25662.6,
#  25659.0,
#  25669.3,
#  25741.7,
#  25791.8,
#  25828.4,
#  25816.9,
#  25856.6,
#  25814.4,
#  25892.8,
#  25854.9,
#  25823.3,
#  25827.5,
#  25791.5,
#  25903.1,
#  25979.7,
#  25972.5,
#  26026.4,
#  25976.7,
#  25958.3,
#  25881.5,
#  25897.3,
#  25877.0,
#  25922.8,
#  25872.6,
#  25821.5,
#  25861.6,
#  25896.1,
#  25890.8,
#  25933.0,
#  25994.1,
#  26034.3,
#  26076.1,
#  26067.6,
#  26037.8,
#  25833.8,
#  25702.7,
#  25633.4,
#  25719.3,
#  25720.3,
#  25663.5,
#  25661.7,
#  25821.4,
#  25920.8,
#  25934.7,
#  26004.3,
#  26023.6,
#  25978.5,
#  25984.3,
#  25983.6,
#  25981.0,
#  25981.6,
#  25912.2,
#  26023.9,
#  26057.0,
#  26052.8,
#  26062.4,
#  26052.7,
#  26076.5,
#  26078.5,
#  26024.0,
#  26016.3,
#  26031.3,
#  26030.0,
#  25990.4,
#  26026.4,
#  26109.3,
#  26138.0,
#  26163.5,
#  26316.1,
#  26313.6,
#  26301.0,
#  26296.0,
#  26388.2,
#  26389.5,
#  26260.3]

# %%
sell_prices
# Out:
# [26455.7,
#  26319.2,
#  26189.9,
#  26202.1,
#  26198.6,
#  26225.6,
#  26227.7,
#  26210.6,
#  26158.9,
#  26131.1,
#  26114.8,
#  26218.1,
#  26163.4,
#  26105.6,
#  26154.1,
#  26151.7,
#  26122.0,
#  25999.7,
#  25909.1,
#  25930.0,
#  25906.2,
#  25780.7,
#  25799.3,
#  25742.6,
#  25636.5,
#  25568.9,
#  25679.7,
#  25252.1,
#  25230.9,
#  25140.2,
#  25263.8,
#  25420.4,
#  25373.5,
#  25599.0,
#  25638.6,
#  25663.9,
#  25670.3,
#  25684.2,
#  25794.8,
#  25800.4,
#  25796.4,
#  25820.3,
#  25813.0,
#  25886.9,
#  25793.8,
#  25764.0,
#  25801.9,
#  25800.9,
#  25903.7,
#  25958.3,
#  25977.3,
#  25985.7,
#  25958.2,
#  25879.0,
#  25885.3,
#  25877.3,
#  25881.2,
#  25859.9,
#  25812.4,
#  25811.0,
#  25831.6,
#  25894.7,
#  25877.4,
#  25913.7,
#  25990.9,
#  26021.0,
#  26063.7,
#  26035.3,
#  25857.2,
#  25711.8,
#  25510.7,
#  25650.1,
#  25767.5,
#  25678.2,
#  25680.2,
#  25678.7,
#  25824.8,
#  25947.8,
#  25923.6,
#  25983.2,
#  26042.6,
#  25978.5,
#  25950.6,
#  25985.5,
#  25988.2,
#  25917.0,
#  25894.8,
#  25976.3,
#  26059.0,
#  26039.4,
#  26059.4,
#  26058.3,
#  26077.2,
#  26005.0,
#  25983.1,
#  26020.1,
#  26023.5,
#  25972.7,
#  25988.9,
#  26026.3,
#  26084.9,
#  26134.7,
#  26165.4,
#  26298.1,
#  26285.5,
#  26298.8,
#  26283.0,
#  26388.2,
#  26228.8,
#  26245.9]

# %%
pip_cost = 1
lot_size = 1
profits = 0
for i in range(len(buy_prices)-1):
    profit = (sell_prices[i] - buy_prices[i]) * 100 * pip_cost * lot_size
    
    profits += profit
    print("The return for trade " + str(i + 1) + " is: " + str(round(profit,2)))
    
print("The return for the period is: " + str(round(profits,2)))
# Out:
# The return for trade 1 is: 260.0
# The return for trade 2 is: -17890.0
# The return for trade 3 is: -12200.0
# The return for trade 4 is: -220.0
# The return for trade 5 is: 190.0
# The return for trade 6 is: -1190.0
# The return for trade 7 is: -70.0
# The return for trade 8 is: -3290.0
# The return for trade 9 is: -5180.0
# The return for trade 10 is: -3290.0
# The return for trade 11 is: -1580.0
# The return for trade 12 is: 780.0
# The return for trade 13 is: -5080.0
# The return for trade 14 is: -6360.0
# The return for trade 15 is: 730.0
# The return for trade 16 is: 500.0
# The return for trade 17 is: -2470.0
# The return for trade 18 is: -12170.0
# The return for trade 19 is: -7540.0
# The return for trade 20 is: -3510.0
# The return for trade 21 is: -1330.0
# The return for trade 22 is: -10910.0
# The return for trade 23 is: 1220.0
# The return for trade 24 is: -2790.0
# The return for trade 25 is: -9450.0
# The return for trade 26 is: -4860.0
# The return for trade 27 is: 4330.0
# The return for trade 28 is: -47480.0
# The return for trade 29 is: -4600.0
# The return for trade 30 is: -11700.0
# The return for trade 31 is: 1590.0
# The return for trade 32 is: 270.0
# The return for trade 33 is: -2550.0
# The return for trade 34 is: -10310.0
# The return for trade 35 is: -2400.0
# The return for trade 36 is: 490.0
# The return for trade 37 is: 100.0
# The return for trade 38 is: -5750.0
# The return for trade 39 is: 300.0
# The return for trade 40 is: -2800.0
# The return for trade 41 is: -2050.0
# The return for trade 42 is: -3630.0
# The return for trade 43 is: -140.0
# The return for trade 44 is: -590.0
# The return for trade 45 is: -6110.0
# The return for trade 46 is: -5930.0
# The return for trade 47 is: -2560.0
# The return for trade 48 is: 940.0
# The return for trade 49 is: 60.0
# The return for trade 50 is: -2140.0
# The return for trade 51 is: 480.0
# The return for trade 52 is: -4070.0
# The return for trade 53 is: -1850.0
# The return for trade 54 is: -7930.0
# The return for trade 55 is: 380.0
# The return for trade 56 is: -2000.0
# The return for trade 57 is: 420.0
# The return for trade 58 is: -6290.0
# The return for trade 59 is: -6020.0
# The return for trade 60 is: -1050.0
# The return for trade 61 is: -3000.0
# The return for trade 62 is: -140.0
# The return for trade 63 is: -1340.0
# The return for trade 64 is: -1930.0
# The return for trade 65 is: -320.0
# The return for trade 66 is: -1330.0
# The return for trade 67 is: -1240.0
# The return for trade 68 is: -3230.0
# The return for trade 69 is: -18060.0
# The return for trade 70 is: -12200.0
# The return for trade 71 is: -19200.0
# The return for trade 72 is: 1670.0
# The return for trade 73 is: 4820.0
# The return for trade 74 is: -4210.0
# The return for trade 75 is: 1670.0
# The return for trade 76 is: 1700.0
# The return for trade 77 is: 340.0
# The return for trade 78 is: 2700.0
# The return for trade 79 is: -1110.0
# The return for trade 80 is: -2110.0
# The return for trade 81 is: 1900.0
# The return for trade 82 is: 0.0
# The return for trade 83 is: -3370.0
# The return for trade 84 is: 190.0
# The return for trade 85 is: 720.0
# The return for trade 86 is: -6460.0
# The return for trade 87 is: -1740.0
# The return for trade 88 is: -4760.0
# The return for trade 89 is: 200.0
# The return for trade 90 is: -1340.0
# The return for trade 91 is: -300.0
# The return for trade 92 is: 560.0
# The return for trade 93 is: 70.0
# The return for trade 94 is: -7350.0
# The return for trade 95 is: -4090.0
# The return for trade 96 is: 380.0
# The return for trade 97 is: -780.0
# The return for trade 98 is: -5730.0
# The return for trade 99 is: -150.0
# The return for trade 100 is: -10.0
# The return for trade 101 is: -2440.0
# The return for trade 102 is: -330.0
# The return for trade 103 is: 190.0
# The return for trade 104 is: -1800.0
# The return for trade 105 is: -2810.0
# The return for trade 106 is: -220.0
# The return for trade 107 is: -1300.0
# The return for trade 108 is: 0.0
# The return for trade 109 is: -16070.0
# The return for the period is: -351650.0
